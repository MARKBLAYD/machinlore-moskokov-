# %% [markdown]
# Лабораторная работа 1. Москоков Иван.
# Ссылка на датасет - https://archive.ics.uci.edu/dataset/429/cryotherapy+dataset

# %% [markdown]
# 1,2) Подключаю библиотеки+работу с гугл диском, загружаю данные

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import mplcyberpunk
sns.set()

from google.colab import drive
drive.mount('/content/drive/')

cryotherapy= pd.read_csv('/content/Cryotherapy.csv')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
pip install mplcyberpunk

# %% [markdown]
# 3) Вывод статистической информации

# %%
cryotherapy.describe()
# Out:
#              sex        age       Time  Number_of_Warts       Type  \
# count  90.000000  90.000000  90.000000        90.000000  90.000000
# mean    1.477778  28.600000   7.666667         5.511111   1.700000
# std     0.502304  13.360852   3.406661         3.567155   0.905042
# min     1.000000  15.000000   0.250000         1.000000   1.000000
# 25%     1.000000  18.000000   4.562500         2.000000   1.000000
# 50%     1.000000  25.500000   8.500000         5.000000   1.000000
# 75%     2.000000  35.000000  10.687500         8.000000   3.000000
# max     2.000000  67.000000  12.000000        12.000000   3.000000
#
#              Area  Result_of_Treatment
# count   90.000000            90.000000
# mean    85.833333             0.533333
# std    131.733153             0.501683
# min      4.000000             0.000000
# 25%     20.000000             0.000000
# 50%     70.000000             1.000000
# 75%    100.000000             1.000000
# max    750.000000             1.000000

# %%
cryotherapy.head()
plt.style.use("cyberpunk")
sns.heatmap(cryotherapy.corr(numeric_only = True));

# %% [markdown]
# 6) Визуализация

# %%
sns.countplot(x=cryotherapy["sex"]);

# %%
plt.style.use("cyberpunk")
cryotherapy.age.hist();

# %%
plt.scatter(cryotherapy['Time'], cryotherapy['Result_of_Treatment'], alpha=0.5)
plt.style.use("cyberpunk")
plt.show()

# %%
plt.plot(cryotherapy['Number_of_Warts'], cryotherapy['Type'])
plt.style.use("cyberpunk")
plt.show()

# %%
sns.lineplot(data=cryotherapy, x="Type", y="Area")
plt.style.use("cyberpunk")
plt.show()

# %%
sns.barplot(x="Area", y="Number_of_Warts", data=cryotherapy)
plt.style.use("cyberpunk")
plt.show()
